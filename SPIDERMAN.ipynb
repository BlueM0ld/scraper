# %% [markdown]
# <a href="https://colab.research.google.com/github/BlueM0ld/scraper/blob/Algolia/SPIDERMAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install virtualenv
# !virtualenv myenv
# !source myenv/bin/activate

# %%
# !pip install scrapy
# !pip install json

# %%
# !scrapy startproject mycrawler
# Out:
# New Scrapy project 'mycrawler', using template directory '/usr/local/lib/python3.10/dist-packages/scrapy/templates/project', created in:
#     /content/mycrawler
#
# You can start your first spider with:
#     cd mycrawler
#     scrapy genspider example example.com

# %%
pwd
# Out:
# '/content/mycrawler'

# %%
# %cd mycrawler/
# Out:
# /content/mycrawler/mycrawler

# %%
# %cd spiders/
# !touch content_scraper_spider_.py
# Out:
# /content/mycrawler/mycrawler/spiders

# %%
#This is content_scraper_spider_.py
# import scrapy
# import json

# class ContentSpider(scrapy.Spider):
#     name = 'content'
    
#     custom_settings = {
#         'FEED_FORMAT': 'json',
#         'FEED_URI': 'content.json',
#         'overwrite': True,
#     }

#     def start_requests(self):
      
#         # Read the links from the JSON file
#         with open('../../links.json') as file:
#             data = json.load(file)

        
#         # Extract the links and yield requests for each link
#         for item in data:
#             link = item['link']
#             if link is not None:
#               if not link.startswith("https://www.algolia.com/"):
#                 page_url = ("https://www.algolia.com/" + link)

#             yield scrapy.Request(url=page_url, callback=self.parse)

#     def parse(self, response):
#         # Extract the content from the response

#         p_chunk = response.xpath('//div/p/text()').extract()
#         title = response.xpath('//h1/text()').get()
#         subtitle =  response.xpath('//h1/following-sibling::div//text()').get()
        
#         # Process and store the extracted content as needed

#         # for p in p_chunk:
#         #     yield {}
#         yield {
#               'title': title,
#               'subtitle': subtitle,
#               'p_text': p_chunk
#           }

# %%
# !touch link_spider_.py

# %%
#This is link spider
# import scrapy


# class LinkSpider(scrapy.Spider):
#     name = 'link'
#     start_urls = ['https://www.algolia.com/doc/']

#     custom_settings = {
#         'FEED_FORMAT': 'json',
#         'FEED_URI': 'links.json'
#     }

#     def parse(self, response):
#         # Extract all links on the page
#         links = response.css('a::attr(href)').getall()
        
#         # Yield each link
#         for link in links:
#             yield {
#                 'link': link
#             }

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !scrapy crawl link
# Out:
# 2023-05-30 09:27:21 [scrapy.utils.log] INFO: Scrapy 2.9.0 started (bot: mycrawler)
# 2023-05-30 09:27:21 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0], pyOpenSSL 23.1.1 (OpenSSL 3.1.0 14 Mar 2023), cryptography 40.0.2, Platform Linux-5.15.107+-x86_64-with-glibc2.31
# 2023-05-30 09:27:21 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'mycrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'mycrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['mycrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-05-30 09:27:21 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-05-30 09:27:21 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...

# %%
# %cd mycrawler/
# Out:
# /content/mycrawler/mycrawler

# %%
# %cd spiders
# Out:
# /content/mycrawler/mycrawler/spiders

# %%
# !scrapy crawl content
# Out:
# 2023-05-30 09:28:55 [scrapy.utils.log] INFO: Scrapy 2.9.0 started (bot: mycrawler)
# 2023-05-30 09:28:55 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0], pyOpenSSL 23.1.1 (OpenSSL 3.1.0 14 Mar 2023), cryptography 40.0.2, Platform Linux-5.15.107+-x86_64-with-glibc2.31
# 2023-05-30 09:28:55 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'mycrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'mycrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['mycrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-05-30 09:28:55 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-05-30 09:28:55 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...
